# %%
import pandas as pd

# %% [markdown]
# # Population Analysis
# Reading and merging the scraped country and region data.

# %%
countries = pd.read_csv("countries.csv")
regions = pd.read_csv("regions.csv")
countries.head()
# Out:
#    rank        country     population yearly_change  net_change density  \
# 0     1          India  1,476,625,576         0.87%  12,760,051     497
# 1     2          China  1,412,914,089        −0.22%  −3,182,005     150
# 2     3  United States    349,035,494         0.51%   1,759,687      38
# 3     4      Indonesia    287,886,782         0.76%   2,165,546     159
# 4     5       Pakistan    259,299,791          1.6%   4,080,237     336
#
#    land_area    migrants  fertility_rate  median_age urban_pop world_share
# 0  2,973,190    −440,456            1.93        29.2     37.6%       17.8%
# 1  9,388,211    −232,107            1.03        40.6     68.7%         17%
# 2  9,147,420   1,177,848            1.63        38.7     83.1%        4.2%
# 3  1,811,570     −39,472            2.08        30.7     60.3%        3.5%
# 4    770,880  −1,144,738            3.44        20.8     34.7%        3.1%

# %% [markdown]
# Checking whether any country names fail to match between the two CSVs before we merge them

# %%
countries_set = set(countries["country"])
regions_set = set(regions["country"])
countries_set - regions_set
# Out:
# {'Brunei',
#  'Czech Republic (Czechia)',
#  'Hong Kong',
#  'Macao',
#  'North Macedonia',
#  'Saint Barthelemy',
#  'Saint Kitts & Nevis',
#  'Saint Pierre & Miquelon',
#  'Sao Tome & Principe',
#  'St. Vincent & Grenadines',
#  'Turks and Caicos',
#  'U.S. Virgin Islands',
#  'Wallis & Futuna'}

# %% [markdown]
# Rename and merge

# %%
renames = {"Czech Republic (Czechia)": "Czechia",
    "Hong Kong": "China, Hong Kong SAR",
    "Macao": "China, Macao SAR",
    "North Macedonia": "Republic of North Macedonia",
    "Brunei": "Brunei Darussalam",
    "Saint Barthelemy": "Saint Barthélemy",
    "Saint Kitts & Nevis": "Saint Kitts and Nevis",
    "Saint Pierre & Miquelon": "Saint Pierre and Miquelon",
    "Sao Tome & Principe": "Sao Tome and Principe",
    "St. Vincent & Grenadines": "Saint Vincent and the Grenadines",
    "Turks and Caicos": "Turks and Caicos Islands",
    "U.S. Virgin Islands": "United States Virgin Islands",
    "Wallis & Futuna": "Wallis and Futuna Islands",
  }
for old_name, new_name in renames.items():
    countries.loc[countries["country"] == old_name, "country"] = new_name

# %% [markdown]
# Check: returns set() if everything is good

# %%
countries_set = set(countries["country"])
regions_set = set(regions["country"])
countries_set - regions_set
# Out:
# set()

# %% [markdown]
# ## Merging the datasets

# %%
data = pd.merge(countries, regions, on="country")
data.head()
# Out:
#    rank        country     population yearly_change  net_change density  \
# 0     1          India  1,476,625,576         0.87%  12,760,051     497
# 1     2          China  1,412,914,089        −0.22%  −3,182,005     150
# 2     3  United States    349,035,494         0.51%   1,759,687      38
# 3     4      Indonesia    287,886,782         0.76%   2,165,546     159
# 4     5       Pakistan    259,299,791          1.6%   4,080,237     336
#
#    land_area    migrants  fertility_rate  median_age urban_pop world_share  \
# 0  2,973,190    −440,456            1.93        29.2     37.6%       17.8%
# 1  9,388,211    −232,107            1.03        40.6     68.7%         17%
# 2  9,147,420   1,177,848            1.63        38.7     83.1%        4.2%
# 3  1,811,570     −39,472            2.08        30.7     60.3%        3.5%
# 4    770,880  −1,144,738            3.44        20.8     34.7%        3.1%
#
#           continent
# 0              Asia
# 1              Asia
# 2  Northern America
# 3              Asia
# 4              Asia

# %% [markdown]
# ## Cleaning numeric columns
#
# Some columns were read in as text because they contain commas, percent signs, or theminus sign. Converting them to real numbers so we can do math and make charts with them.

# %%
def clean_number(text):
      text = text.replace(",", "")
      text = text.replace("%", "")
      text = text.replace("−", "-")
      text = text.replace("–", "nan")
      return text
  
  
data["population"] = [int(clean_number(value)) for value in data["population"]]
data["yearly_change"] = [float(clean_number(value)) for value in data["yearly_change"]]
data["net_change"] = [int(clean_number(value)) for value in data["net_change"]]
data["land_area"] = [int(clean_number(value)) for value in data["land_area"]]
data["migrants"] = [int(clean_number(value)) for value in data["migrants"]]
data["urban_pop"] = [float(clean_number(value)) for value in data["urban_pop"]]
data["world_share"] = [float(clean_number(value)) for value in data["world_share"]]
data["density"] = [int(clean_number(value)) for value in data["density"]]
data.head()
# Out:
#    rank        country  population  yearly_change  net_change  density  \
# 0     1          India  1476625576           0.87    12760051      497
# 1     2          China  1412914089          -0.22    -3182005      150
# 2     3  United States   349035494           0.51     1759687       38
# 3     4      Indonesia   287886782           0.76     2165546      159
# 4     5       Pakistan   259299791           1.60     4080237      336
#
#    land_area  migrants  fertility_rate  median_age  urban_pop  world_share  \
# 0    2973190   -440456            1.93        29.2       37.6         17.8
# 1    9388211   -232107            1.03        40.6       68.7         17.0
# 2    9147420   1177848            1.63        38.7       83.1          4.2
# 3    1811570    -39472            2.08        30.7       60.3          3.5
# 4     770880  -1144738            3.44        20.8       34.7          3.1
#
#           continent
# 0              Asia
# 1              Asia
# 2  Northern America
# 3              Asia
# 4              Asia

# %% [markdown]
# # Section 1 - Continent comparison
#
# ### *How do density, fertility rate, median age, and urbanization compare across continents, and which continent is highest on each?*

# %%
continent_averages = data.groupby("continent")[["density", "fertility_rate", "median_age", "urban_pop"]].mean()
continent_averages
# Out:
#                                      density  fertility_rate  median_age  \
# continent
# Africa                            136.965517        3.591897   21.846552
# Asia                             1055.843137        2.057843   31.323529
# Europe                            813.510638        1.461277   43.334043
# Latin America and the Caribbean   200.560000        1.738800   35.168000
# Northern America                  271.000000        1.512000   41.800000
# Oceania                           130.391304        2.508696   29.147826
#
#                                  urban_pop
# continent
# Africa                           49.764912
# Asia                             60.545833
# Europe                           72.013636
# Latin America and the Caribbean  65.673171
# Northern America                 86.875000
# Oceania                          55.425000

# %%
for column in ["density", "fertility_rate", "median_age", "urban_pop"]:
    top = continent_averages.sort_values(column, ascending=False).head(1)
    print(column)
    print(top)
# Out:
# density
#                density  fertility_rate  median_age  urban_pop
# continent
# Asia       1055.843137        2.057843   31.323529  60.545833
# fertility_rate
#               density  fertility_rate  median_age  urban_pop
# continent
# Africa     136.965517        3.591897   21.846552  49.764912
# median_age
#               density  fertility_rate  median_age  urban_pop
# continent
# Europe     813.510638        1.461277   43.334043  72.013636
# urban_pop
#                   density  fertility_rate  median_age  urban_pop
# continent
# Northern America    271.0           1.512        41.8     86.875

# %%
continent_averages.plot.bar()
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# ### Takeaway
#
# tyuioiuytrdsdfjk

# %% [markdown]
# # Section 2 - Fertility rate vs. median age
#
# ### Is there a relationship between how many children women have on average and how old the median citizen is?

# %%
data.plot.scatter(x="fertility_rate", y="median_age")
# Out:
# <Axes: xlabel='fertility_rate', ylabel='median_age'>

# %% [markdown]
# ### Takeaway
#
# jhgfdfghjkl

# %% [markdown]
# # Section 3 - Rankings
#
# ### Which countries are most/least densely populated, most/least urbanized, and which gained or lost the most population this year?

# %%
data.sort_values("density", ascending=False)[["country", "density"]].head(10)
# Out:
#                   country  density
# 215                Monaco    25562
# 166      China, Macao SAR    24106
# 114             Singapore     8437
# 106  China, Hong Kong SAR     7027
# 212             Gibraltar     4087
# 152               Bahrain     2205
# 172              Maldives     1772
# 171                 Malta     1716
# 7              Bangladesh     1366
# 210          Sint Maarten     1307

# %%
data.sort_values("density")[["country", "density"]].head(10)
# Out:
#               country  density
# 206         Greenland        0
# 230  Falkland Islands        0
# 132          Mongolia        2
# 170    Western Sahara        2
# 54          Australia        4
# 104             Libya        4
# 37             Canada        4
# 136           Namibia        4
# 182     French Guiana        4
# 164            Guyana        4

# %%
data.sort_values("urban_pop", ascending=False)[["country", "urban_pop"]].head(10)
# Out:
#               country  urban_pop
# 210      Sint Maarten       99.6
# 82            Belgium       99.0
# 190              Guam       98.9
# 166  China, Macao SAR       98.3
# 170    Western Sahara       97.6
# 34          Argentina       96.5
# 135             Qatar       96.2
# 182     French Guiana       95.2
# 223             Nauru       93.8
# 11              Japan       93.4

# %%
data.sort_values("urban_pop")[["country", "urban_pop"]].head(10)
# Out:
#               country  urban_pop
# 229        Montserrat       11.7
# 88   Papua New Guinea       12.7
# 213     Liechtenstein       14.8
# 77            Burundi       15.4
# 187             Samoa       16.3
# 59          Sri Lanka       18.2
# 52              Niger       18.5
# 76             Rwanda       18.5
# 189       Saint Lucia       20.1
# 61             Malawi       20.2

# %%
data.sort_values("net_change", ascending=False)[["country", "net_change"]].head(10)
# Out:
#           country  net_change
# 0           India    12760051
# 5         Nigeria     4904050
# 4        Pakistan     4080237
# 14       DR Congo     3619689
# 9        Ethiopia     3430134
# 3       Indonesia     2165546
# 7      Bangladesh     2131145
# 19       Tanzania     2017915
# 2   United States     1759687
# 12          Egypt     1735180

# %%
data.sort_values("net_change")[["country", "net_change"]].head(10)
# Out:
#         country  net_change
# 1         China    -3182005
# 11        Japan     -675748
# 8        Russia     -602935
# 18      Germany     -430817
# 41       Poland     -297722
# 24        Italy     -220094
# 69      Romania     -108045
# 60       Taiwan     -101501
# 91      Czechia      -81458
# 30  South Korea      -66641

# %% [markdown]
# ### Takeaway
#
# kjhgfdfghjkl;

# %% [markdown]
# # Section 4: Population share by continent
#
# ### How is the world's population distributed across continents, and is that share shifting?

# %%
continent_share = data.groupby("continent")["world_share"].sum()
continent_share
# Out:
# continent
# Africa                             19.042662
# Asia                               58.550500
# Europe                              8.931726
# Latin America and the Caribbean     8.119064
# Northern America                    4.691516
# Oceania                             0.562494
# Name: world_share, dtype: float64

# %%
continent_share.plot.bar()
# Out:
# <Axes: xlabel='continent'>

# %%
continent_growth = data.groupby("continent")["yearly_change"].mean()
continent_growth.plot.bar()
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# ### Takeaway
# jyhgtfsfdghjkl
